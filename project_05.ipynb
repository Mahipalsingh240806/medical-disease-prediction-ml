# %%
import numpy as np  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\mahip\Desktop\project 05\medical_disease_prediction_10000.csv')
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.head()
# Out:
#    Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0   23    Male  17.5            102           177          161         88
# 1   69    Male  31.1            118           256          147         92
# 2   61  Female  31.3            114           206          193         74
# 3   47  Female  23.9            105           162          253         68
# 4   47    Male  28.3            148           121          280         84
#
#   Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 0      No      No           Medium            No       Healthy
# 1      No      No             High           Yes  Pre-Diabetes
# 2     Yes      No           Medium            No       Healthy
# 3      No      No              Low            No       Healthy
# 4      No     Yes             High            No       Healthy

# %%
df.tail()
# Out:
#       Age Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 9995   49   Male  27.1            177           183          268         59
# 9996   84   Male  29.2            142           215          145         77
# 9997   41   Male  22.8            177           265          133         71
# 9998   55   Male  29.0            126           241          298         57
# 9999   59   Male  32.2            151           162          225         93
#
#      Smoking Alcohol PhysicalActivity FamilyHistory       Disease
# 9995      No      No             High            No  Hypertension
# 9996      No     Yes             High           Yes  Hypertension
# 9997      No      No           Medium           Yes  Hypertension
# 9998      No      No           Medium           Yes  Pre-Diabetes
# 9999      No      No             High           Yes  Pre-Diabetes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
df.describe()
# Out:
#                 Age           BMI  BloodPressure  GlucoseLevel   Cholesterol  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean      50.755300     26.082000     135.023800    175.252000    219.313500
# std       19.242137      4.461098      26.249406     60.536159     57.940956
# min       18.000000     16.000000      90.000000     70.000000    120.000000
# 25%       34.000000     23.000000     112.000000    123.000000    169.000000
# 50%       51.000000     26.000000     135.000000    174.000000    219.000000
# 75%       67.000000     29.100000     158.000000    227.000000    269.250000
# max       84.000000     44.700000     180.000000    280.000000    320.000000
#
#           HeartRate
# count  10000.000000
# mean      82.690100
# std       16.167628
# min       55.000000
# 25%       69.000000
# 50%       83.000000
# 75%       97.000000
# max      110.000000

# %%
df.isnull()
# Out:
#         Age  Gender    BMI  BloodPressure  GlucoseLevel  Cholesterol  \
# 0     False   False  False          False         False        False
# 1     False   False  False          False         False        False
# 2     False   False  False          False         False        False
# 3     False   False  False          False         False        False
# 4     False   False  False          False         False        False
# ...     ...     ...    ...            ...           ...          ...
# 9995  False   False  False          False         False        False
# 9996  False   False  False          False         False        False
# 9997  False   False  False          False         False        False
# 9998  False   False  False          False         False        False
# 9999  False   False  False          False         False        False
#
#       HeartRate  Smoking  Alcohol  PhysicalActivity  FamilyHistory  Disease
# ...

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'BloodPressure', 'GlucoseLevel', 'Cholesterol',
#        'HeartRate', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='str')

# %%
df['Age'].agg(["min","max","mean"])
# Out:
# min     18.0000
# max     84.0000
# mean    50.7553
# Name: Age, dtype: float64

# %%
df["BMI"].agg(["min","max","mean"])
# Out:
# min     16.000
# max     44.700
# mean    26.082
# Name: BMI, dtype: float64

# %%
df["BloodPressure"].agg(["min","max","mean"])
# Out:
# min      90.0000
# max     180.0000
# mean    135.0238
# Name: BloodPressure, dtype: float64

# %%
df["GlucoseLevel"].agg(["min","max","mean"])
# Out:
# min      70.000
# max     280.000
# mean    175.252
# Name: GlucoseLevel, dtype: float64

# %%
df["Cholesterol"].agg(["min","max","mean"])
# Out:
# min     120.0000
# max     320.0000
# mean    219.3135
# Name: Cholesterol, dtype: float64

# %%
df["HeartRate"].agg(["min",'max',"mean"])
# Out:
# min      55.0000
# max     110.0000
# mean     82.6901
# Name: HeartRate, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'BloodPressure', 'GlucoseLevel', 'Cholesterol',
#        'HeartRate', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='str')

# %%
df['Age'].unique()
# Out:
# array([23, 69, 61, 47, 75, 64, 31, 24, 53, 83, 67, 68, 66, 70, 52, 26, 74,
#        48, 51, 42, 30, 80, 44, 73, 54, 33, 55, 77, 22, 36, 60, 29, 41, 63,
#        49, 20, 28, 79, 82, 45, 39, 78, 71, 40, 62, 81, 38, 43, 37, 34, 27,
#        18, 65, 56, 25, 58, 32, 84, 21, 46, 72, 19, 35, 57, 59, 50, 76])

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df['Disease'].unique()
# Out:
# <StringArray>
# ['Healthy', 'Pre-Diabetes', 'Hypertension', 'Heart Disease', 'Diabetes']
# Length: 5, dtype: str

# %%
df['FamilyHistory'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df['Alcohol'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df['HeartRate'].unique()
# Out:
# array([ 88,  92,  74,  68,  84,  59,  71, 107,  97,  72,  58,  76,  93,
#         57, 103, 104,  89,  64,  69,  81, 109,  99,  62,  87,  90,  63,
#         66, 105,  56,  86, 102,  94,  79,  61, 106,  73,  77,  95,  60,
#         83,  55,  65, 100, 110,  98, 101,  70,  75,  67,  80,  91,  85,
#        108,  82,  96,  78])

# %%
df['PhysicalActivity'].unique()
# Out:
# <StringArray>
# ['Medium', 'High', 'Low']
# Length: 3, dtype: str

# %%
df['Smoking'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
Gender_dict ={'Male' : 0,
            'Female' : 1}

# %%
df['Gender'] = df['Gender'].map(Gender_dict)

# %%
df['Gender']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %%
Disease_dict = {'Healthy' : 1,
                'Pre-Diabetes' : 2,
                'Hypertension' : 3,
                'Heart Disease' : 4,
                'Diabetes' : 5
                }

# %%
df['Disease'] = df['Disease'].map(Disease_dict)

# %%
df['Disease']
# Out:
# 0       1
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 9995    3
# 9996    3
# 9997    3
# 9998    2
# 9999    2
# Name: Disease, Length: 10000, dtype: int64

# %%
FamilyHistory_dict = {'No' : 0,
                    'Yes' : 1 
                    }

# %%
df['FamilyHistory'] = df['FamilyHistory'].map(FamilyHistory_dict)

# %%
df['FamilyHistory']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: FamilyHistory, Length: 10000, dtype: int64

# %%
Alcohol_dict = {'No' : 0,
                'Yes' : 1 
                }

# %%
df['Alcohol'] = df['Alcohol'].map(Alcohol_dict)

# %%
df['Alcohol']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    0
# 9998    0
# 9999    0
# Name: Alcohol, Length: 10000, dtype: int64

# %%
PhysicalActivity_dict = {'Medium' : 0,
                        'High' : 1,
                        'Low' : 2 }

# %%
df['PhysicalActivity'] = df['PhysicalActivity'].map(PhysicalActivity_dict)

# %%
df['PhysicalActivity']
# Out:
# 0       0
# 1       1
# 2       0
# 3       2
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    0
# 9999    1
# Name: PhysicalActivity, Length: 10000, dtype: int64

# %%
Smoking_dict = {'No' : 0,
                'Yes' : 1 
                }

# %%
df['Smoking'] = df['Smoking'].map(Smoking_dict)

# %%
df['Smoking']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Smoking, Length: 10000, dtype: int64

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Disease', data=df)

plt.title("Disease Distribution")
plt.xlabel("Disease")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df)

plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['BMI'], bins=20, kde=True)

plt.title("BMI Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['GlucoseLevel'], bins=20, kde=True)

plt.title("Glucose Level Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Cholesterol'], bins=20, kde=True)

plt.title("Cholesterol Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['BloodPressure'], bins=20, kde=True)

plt.title("Blood Pressure Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Disease', y='Age', data=df)

plt.title("Age vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Disease', y='BMI', data=df)

plt.title("BMI vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Disease', y='GlucoseLevel', data=df)

plt.title("Glucose Level vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Disease', y='Cholesterol', data=df)

plt.title("Cholesterol vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Disease', y='BloodPressure', data=df)

plt.title("Blood Pressure vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Smoking', hue='Disease', data=df)

plt.title("Smoking vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Alcohol', hue='Disease', data=df)

plt.title("Alcohol vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='FamilyHistory', hue='Disease', data=df)

plt.title("Family History vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='PhysicalActivity', hue='Disease', data=df)

plt.title("Physical Activity vs Disease")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='Age',
    y='GlucoseLevel',
    hue='Disease',
    data=df
)

plt.title("Age vs Glucose Level")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='BMI',
    y='Cholesterol',
    hue='Disease',
    data=df
)

plt.title("BMI vs Cholesterol")
plt.show()

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(
    df[['Age',
        'BMI',
        'BloodPressure',
        'GlucoseLevel',
        'Cholesterol',
        'HeartRate',
        'Disease']]
)
plt.show()
